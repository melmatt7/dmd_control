# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns #library to make the plots look fancy
from matplotlib.ticker import MultipleLocator
from scipy.io import loadmat  # this is the SciPy module that loads mat-files

# for tutorials look here: https://seaborn.pydata.org/tutorial.html

sns.set_style("whitegrid")
results_path = "../../raw_results/picoscope/fourier/"

# %%
name = "5k"
file = results_path + name + ".mat"

save_path = "fourier_results/"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
# plt.ylim(0.0065,0.012)
plt.figure(1,figsize=(10,5))
plt.xlim(0,20e3)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,5))
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
# plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.22074038e+00 2.44148077e+00 ... 3.99926757e+04
#  3.99938964e+04 3.99951172e+04]

# %%
name = "10k"
file = results_path + name + ".mat"

save_path = "fourier_results/"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
# plt.ylim(0.0065,0.012)
plt.figure(1,figsize=(10,5))
plt.xlim(0,20e3)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,5))
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
# plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 6.10370192e+00 1.22074038e+01 ... 1.99963379e+05
#  1.99969482e+05 1.99975586e+05]

# %%
name = "50k"
file = results_path + name + ".mat"

save_path = "fourier_results/"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
# plt.ylim(0.0065,0.012)
plt.figure(1,figsize=(10,5))
plt.xlim(0,200e3)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
# plt.ticklabel_format(axis="x", style="sci", scilimits=(0,5))
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
# plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 6.10370192e+00 1.22074038e+01 ... 1.99963379e+05
#  1.99969482e+05 1.99975586e+05]

# %%
name = "100k"
file = results_path + name + ".mat"

save_path = "fourier_results/"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
# plt.ylim(0.0065,0.012)
plt.figure(1,figsize=(10,5))
plt.xlim(0,200e3)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
# plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.22074038e+01 2.44148077e+01 ... 3.99926757e+05
#  3.99938964e+05 3.99951172e+05]

# %%
name = "150k"
file = results_path + name + ".mat"

save_path = "fourier_results/"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
# plt.ylim(0.0065,0.012)
plt.figure(1,figsize=(10,5))
plt.xlim(0,300e3)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
# plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 6.10370192e+01 1.22074038e+02 ... 1.99963379e+06
#  1.99969482e+06 1.99975586e+06]

# %%
name = "200k"
file = results_path + name + ".mat"

save_path = "fourier_results/"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
# plt.ylim(0.0065,0.012)
plt.figure(1,figsize=(10,5))
plt.xlim(0,300e3)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
# plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 3.05185096e+01 6.10370192e+01 ... 9.99816893e+05
#  9.99847411e+05 9.99877930e+05]

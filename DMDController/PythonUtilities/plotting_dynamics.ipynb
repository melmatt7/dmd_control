# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns #library to make the plots look fancy
from matplotlib.ticker import MultipleLocator
from scipy.io import loadmat  # this is the SciPy module that loads mat-files

# for tutorials look here: https://seaborn.pydata.org/tutorial.html

sns.set_style("whitegrid")
path = "../../../picoscope/dynamics/"

# %%
name = "10k_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.007,0.017)
plt.xlim(0.25e-4,1.47e-4)
plt.plot(time, data["A"])
# plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25007806e-08 2.50015611e-08 ... 1.99974987e-04
#  1.99987487e-04 1.99999988e-04]

# %%
name = "50k_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.007,0.018)
plt.xlim(5e-5,8e-5)
plt.plot(time, data["A"])
# plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25015620e-08 2.50031239e-08 ... 9.99749909e-05
#  9.99874925e-05 9.99999941e-05]

# %%
name = "100k_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.007,0.017)
plt.xlim(1.7e-5,3.2e-5)
plt.plot(time, data["A"])
# plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25031172e-08 2.50062345e-08 ... 5.00999908e-05
#  5.01124939e-05 5.01249970e-05]

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns #library to make the plots look fancy
from matplotlib.ticker import MultipleLocator
from scipy.io import loadmat  # this is the SciPy module that loads mat-files

# for tutorials look here: https://seaborn.pydata.org/tutorial.html

sns.set_style("whitegrid")
path = "../../../picoscope/latency/"

# %%
name = "100_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.007,0.018)
plt.xlim(1.44e-3, 1.48e-3)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25000774e-08 2.50001548e-08 ... 1.99997488e-03
#  1.99998738e-03 1.99999988e-03]

# %%
name = "1k_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.006,0.018)
plt.xlim(18.1e-4,18.45e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25000305e-08 2.50000610e-08 ... 4.99997470e-03
#  4.99998720e-03 4.99999970e-03]

# %%
name = "10k_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.007,0.017)
plt.xlim(1.0e-4,1.35e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "100_dual"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00, 0.035)
plt.xlim(0.00266, 0.00271)
plt.plot(time, data["A"])
plt.plot(time, data["C"])

plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25000305e-08 2.50000610e-08 ... 4.99997470e-03
#  4.99998720e-03 4.99999970e-03]

# %%
name = "1k_dual"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.005,0.035)
plt.xlim(3.9e-4, 4.4e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "10k_dual"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.005,0.035)
plt.xlim(2.65e-4, 3.1e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "100_quad"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.005,0.05)
plt.xlim(11.4e-4, 11.9e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25000774e-08 2.50001548e-08 ... 1.99997488e-03
#  1.99998738e-03 1.99999988e-03]

# %%
name = "1k_quad"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.06)
plt.xlim(1.3e-4, 1.8e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "10k_quad"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.06)
plt.xlim(0e-5, 4.5e-5)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25015620e-08 2.50031239e-08 ... 9.99749909e-05
#  9.99874925e-05 9.99999941e-05]

# %%
name = "100_global"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(7.9e-4, 8.7e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25001555e-08 2.50003110e-08 ... 9.99974940e-04
#  9.99987440e-04 9.99999941e-04]

# %%
name = "1k_global"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0,0.10)
plt.xlim(1.6e-4, 2.5e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "10k_global"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0,0.10)
plt.xlim(0.1e-4,1e-4)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25015620e-08 2.50031239e-08 ... 9.99749909e-05
#  9.99874925e-05 9.99999941e-05]

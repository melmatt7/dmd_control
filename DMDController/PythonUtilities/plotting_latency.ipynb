# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns #library to make the plots look fancy
from matplotlib.ticker import MultipleLocator
from scipy.io import loadmat  # this is the SciPy module that loads mat-files

# for tutorials look here: https://seaborn.pydata.org/tutorial.html

sns.set_style("whitegrid")
path = "../../raw_results/picoscope/latency/"
step = 1e-4

# %%
name = "100_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(2.4e-4, 2.4e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [-0.00050001 -0.0005     -0.00049998 ...  0.00099996  0.00099998
#   0.001     ]

# %%
name = "1k_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0,0.1)
plt.xlim(2.4e-4,2.4e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [-0.00050002 -0.0005     -0.00049998 ...  0.00099996  0.00099998
#   0.001     ]

# %%
name = "10k_single"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(0.9e-4,0.9e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [-0.00050002 -0.0005     -0.00049998 ...  0.00099996  0.00099998
#   0.001     ]

# %%
name = "100_dual"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00, 0.1)
plt.xlim(0.00266, 0.00266+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])

plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25000305e-08 2.50000610e-08 ... 4.99997470e-03
#  4.99998720e-03 4.99999970e-03]

# %%
name = "1k_dual"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(3.9e-4, 3.9e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "10k_dual"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(2.65e-4, 2.65e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "100_quad"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(11.4e-4,11.4e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25000774e-08 2.50001548e-08 ... 1.99997488e-03
#  1.99998738e-03 1.99999988e-03]

# %%
name = "1k_quad"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(1.3e-4, 1.3e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "10k_quad"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(0e-5, 0e-5+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25015620e-08 2.50031239e-08 ... 9.99749909e-05
#  9.99874925e-05 9.99999941e-05]

# %%
name = "100_global"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.00,0.1)
plt.xlim(7.9e-4, 7.9e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25001555e-08 2.50003110e-08 ... 9.99974940e-04
#  9.99987440e-04 9.99999941e-04]

# %%
name = "1k_global"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0,0.10)
plt.xlim(1.6e-4, 1.6e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25003118e-08 2.50006235e-08 ... 4.99974970e-04
#  4.99987470e-04 4.99999970e-04]

# %%
name = "10k_global"
file = path + name + ".mat"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0,0.10)
plt.xlim(0.1e-4,0.1e-4+step)
plt.plot(time, data["A"])
plt.plot(time, data["C"])
plt.savefig(name+".svg")
plt.show()
# Out:
# 0
# [0.00000000e+00 1.25015620e-08 2.50031239e-08 ... 9.99749909e-05
#  9.99874925e-05 9.99999941e-05]

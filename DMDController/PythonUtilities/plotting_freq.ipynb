# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns #library to make the plots look fancy
from matplotlib.ticker import MultipleLocator
from scipy.io import loadmat  # this is the SciPy module that loads mat-files

# for tutorials look here: https://seaborn.pydata.org/tutorial.html

sns.set_style("whitegrid")
results_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\raw_results\\picoscope\\freq\\"

# %%
name = "1k"
file = results_path + name + ".mat"

save_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\DMDController\\PythonUtilities\\freq_results\\"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.006,0.012)
plt.xlim(-0.0003,0.00285)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [-0.00250001 -0.0025     -0.00249998 ...  0.00499996  0.00499998
#   0.005     ]

# %%
name = "10k"
file = results_path + name + ".mat"

save_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\DMDController\\PythonUtilities\\freq_results\\"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.006,0.012)
# plt.xlim(-2e-5,6e-5)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [-1.00013232e-04 -9.99944804e-05 -9.99757284e-05 ...  1.99962484e-04
#   1.99981236e-04  1.99999988e-04]

# %%
name = "100k"
file = results_path + name + ".mat"

save_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\DMDController\\PythonUtilities\\freq_results\\"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0065,0.012)
plt.xlim(0.9e-5,4.1e-5)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [-5.00237002e-05 -5.00049449e-05 -4.99861896e-05 ...  9.99624835e-05
#   9.99812388e-05  9.99999941e-05]

# %%
name = "5k"
file = results_path + name + ".mat"

save_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\DMDController\\PythonUtilities\\freq_results\\"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0065,0.020)
plt.xlim(23e-5,90e-5)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [-0.00050002 -0.0005     -0.00049998 ...  0.00099996  0.00099998
#   0.001     ]

# %%
name = "50k"
file = results_path + name + ".mat"

save_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\DMDController\\PythonUtilities\\freq_results\\"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0065,0.020)
plt.xlim(2.3e-5,9e-5)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [-5.00162678e-05 -4.99975134e-05 -4.99787590e-05 ...  9.99624853e-05
#   9.99812397e-05  9.99999941e-05]

# %%
name = "150k"
file = results_path + name + ".mat"

save_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\DMDController\\PythonUtilities\\freq_results\\"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0065,0.014)
plt.xlim(2.19e-5,4.5e-5)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [-2.50204484e-05 -2.50016886e-05 -2.49829288e-05 ...  4.99624774e-05
#   4.99812372e-05  4.99999970e-05]

# %%
name = "200k"
file = results_path + name + ".mat"

save_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\DMDController\\PythonUtilities\\freq_results\\"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0065,0.018)
plt.xlim(2.70e-5,4.5e-5)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [-2.50169251e-05 -2.49981661e-05 -2.49794072e-05 ...  4.99624792e-05
#   4.99812381e-05  4.99999970e-05]

# %%
name = "10k"
file = results_path + name + ".mat"

save_path = "C:\\Users\\Impact\\Desktop\\Melvin\\dmd_control\\DMDController\\PythonUtilities\\freq_results\\"

data = loadmat(file_name=file)

print(int(data["Tstart"][0][0]))

# for i,a in enumerate(data["A"]):
#     if a > 0.009:
#         data["A"][i] = a*1.1
#     else:
#         data["A"][i] = a
        
# for j,b in enumerate(data["B"]):
#     if b < 0.01 and b > 0.0075:
#         data["B"][j] = b*0.8
#     else:
#         data["B"][j] = b
        
time = np.linspace(data["Tstart"][0][0],data["Length"][0][0]*data["Tinterval"][0][0],int(data["Length"][0][0]))
print(time)
plt.ylim(0.0065,0.020)
plt.xlim(11.5e-5,45e-5)
plt.plot(time, data["A"])
plt.plot(time, data["B"])
plt.plot(time, data["C"])
plt.savefig(save_path+name+".svg")
plt.show()
# Out:
# 0
# [-0.00025001 -0.00024999 -0.00024998 ...  0.00049996  0.00049998
#   0.0005    ]
